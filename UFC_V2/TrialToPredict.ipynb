# %%
from prediction import predict_fight_outcome

# %%
winner = predict_fight_outcome('Jeka Saragih', 'Westin Wilson')
# Out:
# c:\Users\msi\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
winner
# Out:
# 'Westin Wilson'

# %%
import pandas as pd

# %%
data = pd.read_csv('Predictions.csv')

# %%
data
# Out:
#                  Fighter 1               Fighter 2 Old Model Prediction  \
# 0    Charalampos Grigoriou          Chad Anheliger                 loss
# 1           Aiemann Zahabi          Javid Basharat                 Loss
# 2              Ricky Simon          Mario Bautista                 Loss
# 3            Casey O'Neill           Ariane Lipski                 Loss
# 4              Song Yadong         Chris Gutierrez                 Loss
# ..                     ...                     ...                  ...
# 286      Gillian Robertson           Polyana Viana                  win
# 287           Steve Garcia        Melquizael Costa                  Win
# 288         Luana Pinheiro            Amanda Ribas                  Win
# 289          Eduarda Moura  Montserrat Conejo Ruiz                  Win
# 290           Ashley Yoder            Emily Ducote                  Win
#
#     Real Outcome
# 0            L/W
# 1            W/L
# 2            L/W
# 3            W/L
# ...

# %%
data['New Model Outcome'] = None

# Loop through each row in the DataFrame to predict the fight outcome
for i in range(len(data)):
    try:
        winner = predict_fight_outcome(fighter1_name=data['Fighter 1'][i], fighter2_name=data['Fighter 2'][i])
        data.at[i, 'New Model Outcome'] = winner  # Using .at for better performance when setting scalar values
    except:
        data.at[i, 'New Model Outcome'] = "NaN value error"  # Handle exceptions, e.g., missing data
# Out:
# c:\Users\msi\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\msi\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\msi\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\msi\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\msi\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# ...

# %%
data
# Out:
#                  Fighter 1               Fighter 2 Old Model Prediction  \
# 0    Charalampos Grigoriou          Chad Anheliger                 loss
# 1           Aiemann Zahabi          Javid Basharat                 Loss
# 2              Ricky Simon          Mario Bautista                 Loss
# 3            Casey O'Neill           Ariane Lipski                 Loss
# 4              Song Yadong         Chris Gutierrez                 Loss
# ..                     ...                     ...                  ...
# 286      Gillian Robertson           Polyana Viana                  win
# 287           Steve Garcia        Melquizael Costa                  Win
# 288         Luana Pinheiro            Amanda Ribas                  Win
# 289          Eduarda Moura  Montserrat Conejo Ruiz                  Win
# 290           Ashley Yoder            Emily Ducote                  Win
#
#     Real Outcome                                  New Model Outcome
# ...

# %%
data.to_csv('Predictions.csv')

# %% [markdown]
# ## New Model Prediction Outcome

# %%
df = pd.read_csv('Predictions.csv')

# %%
df
# Out:
#                  Fighter 1               Fighter 2 Old Model Prediction  \
# 0    Charalampos Grigoriou          Chad Anheliger                 loss
# 1           Aiemann Zahabi          Javid Basharat                 Loss
# 2              Ricky Simon          Mario Bautista                 Loss
# 3            Casey O'Neill           Ariane Lipski                 Loss
# 4              Song Yadong         Chris Gutierrez                 Loss
# ..                     ...                     ...                  ...
# 286      Gillian Robertson           Polyana Viana                  win
# 287           Steve Garcia        Melquizael Costa                  Win
# 288         Luana Pinheiro            Amanda Ribas                  Win
# 289          Eduarda Moura  Montserrat Conejo Ruiz                  Win
# 290           Ashley Yoder            Emily Ducote                  Win
#
#     Real Outcome                                  New Model Outcome
# ...

# %%
import pandas as pd

# Load your DataFrame
df = pd.read_csv('Predictions.csv')

# Ensure all data in 'Real Outcome' and 'New Model Outcome' are in consistent case format
df['Real Outcome'] = df['Real Outcome'].str.lower()

# Initialize the 'Model Outcome' column
df['Model Outcome'] = None

for i in range(len(df)):
    try:
        real_outcome = df.at[i, 'Real Outcome']
        predicted_winner = df.at[i, 'New Model Outcome']
        fighter1 = df.at[i, 'Fighter 1']

        if real_outcome in ['w/l', 'l/w']:
            # Determine the model outcome based on the real outcome and predicted winner
            if (real_outcome == 'w/l' and predicted_winner == fighter1) or (real_outcome == 'l/w' and predicted_winner != fighter1):
                df.at[i, 'Model Outcome'] = 'Win'
            else:
                df.at[i, 'Model Outcome'] = 'Loss'
    except Exception as e:
        print(f"Error processing row {i}: {e}")

# %%
df.to_csv("Predictions.csv")
